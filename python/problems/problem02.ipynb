# %% [markdown]
# # 모든코인 상승장? 하락장?
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import requests
import pprint
url = "https://api.bithumb.com/public/ticker/all"
data = requests.get(url).json()['data']
pprint.pprint(data)
# Out:
# {'ABT': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '2.04',
#          'average_price': '301.5452',
#          'buy_price': '298',
#          'closing_price': '300',
#          'max_price': '318',
#          'min_price': '284',
#          'opening_price': '294',
#          'sell_price': '300',
#          'units_traded': '1573092.88581994',
#          'volume_1day': '1573092.88581994',
#          'volume_7day': '10457421.661381080946111547'},
#  'ADA': {'24H_fluctate': '4.1',
#          '24H_fluctate_rate': '4.41',
#          'average_price': '96.0513',
#          'buy_price': '96.1',
#          'closing_price': '96.9',
#          'max_price': '103',
#          'min_price': '91.3',
#          'opening_price': '92.8',
#          'sell_price': '96.7',
#          'units_traded': '6512245.7104137',
#          'volume_1day': '6512245.7104137',
#          'volume_7day': '63783938.8751128'},
#  'AE': {'24H_fluctate': '4',
#         '24H_fluctate_rate': '0.76',
#         'average_price': '533.5897',
#         'buy_price': '522',
#         'closing_price': '525',
#         'max_price': '570',
#         'min_price': '505',
#         'opening_price': '521',
#         'sell_price': '525',
#         'units_traded': '438613.21275147',
#         'volume_1day': '438613.21275147',
#         'volume_7day': '2528006.191261433528959624'},
#  'AMO': {'24H_fluctate': '-0.01',
#          '24H_fluctate_rate': '-1.53',
#          'average_price': '0.6409',
#          'buy_price': '0.63',
#          'closing_price': '0.64',
#          'max_price': '0.66',
#          'min_price': '0.61',
#          'opening_price': '0.65',
#          'sell_price': '0.64',
#          'units_traded': '327093612.77887477',
#          'volume_1day': '327093612.77887477',
#          'volume_7day': '3305617842.482424469475093072'},
#  'ANKR': {'24H_fluctate': '0.3',
#           '24H_fluctate_rate': '2.85',
#           'average_price': '10.5455',
#           'buy_price': '10.6',
#           'closing_price': '10.8',
#           'max_price': '11',
#           'min_price': '10.1',
#           'opening_price': '10.5',
#           'sell_price': '10.8',
#           'units_traded': '92769267.18100425',
#           'volume_1day': '92769267.18100425',
#           'volume_7day': '683916743.537400687930143084'},
#  'APIS': {'24H_fluctate': '0.14',
#           '24H_fluctate_rate': '8.43',
#           'average_price': '1.7342',
#           'buy_price': '1.77',
#           'closing_price': '1.8',
#           'max_price': '1.9',
#           'min_price': '1.66',
#           'opening_price': '1.66',
#           'sell_price': '1.79',
#           'units_traded': '65126807.84179579',
#           'volume_1day': '65126807.84179579',
#           'volume_7day': '300755658.896510022513315604'},
#  'ARN': {'24H_fluctate': '12',
#          '24H_fluctate_rate': '2.29',
#          'average_price': '546.1745',
#          'buy_price': '528',
#          'closing_price': '536',
#          'max_price': '586',
#          'min_price': '516',
#          'opening_price': '524',
#          'sell_price': '536',
#          'units_traded': '285220.40802498',
#          'volume_1day': '285220.40802498',
#          'volume_7day': '1681584.9049294'},
#  'AUTO': {'24H_fluctate': '-0.03',
#           '24H_fluctate_rate': '-1.80',
#           'average_price': '1.6686',
#           'buy_price': '1.63',
#           'closing_price': '1.63',
#           'max_price': '1.73',
#           'min_price': '1.62',
#           'opening_price': '1.66',
#           'sell_price': '1.67',
#           'units_traded': '27156140.32465438',
#           'volume_1day': '27156140.32465438',
#           'volume_7day': '314263817.308813603262875436'},
#  'BAT': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '291.4758',
#          'buy_price': '279',
#          'closing_price': '282',
#          'max_price': '305',
#          'min_price': '276',
#          'opening_price': '282',
#          'sell_price': '283',
#          'units_traded': '570666.87572239',
#          'volume_1day': '570666.87572239',
#          'volume_7day': '8683750.730817355292766026'},
#  'BCD': {'24H_fluctate': '330',
#          '24H_fluctate_rate': '17.46',
#          'average_price': '2179.2845',
#          'buy_price': '2190',
#          'closing_price': '2220',
#          'max_price': '2367',
#          'min_price': '1872',
#          'opening_price': '1890',
#          'sell_price': '2220',
#          'units_traded': '830990.68662818',
#          'volume_1day': '830990.68662818',
#          'volume_7day': '1594255.99282278'},
#  'BCH': {'24H_fluctate': '31100',
#          '24H_fluctate_rate': '9.10',
#          'average_price': '368720.7',
#          'buy_price': '373000',
#          'closing_price': '372800',
#          'max_price': '393600',
#          'min_price': '338000',
#          'opening_price': '341700',
#          'sell_price': '373500',
#          'units_traded': '38304.6327566',
#          'volume_1day': '38304.6327566',
#          'volume_7day': '215764.2077531'},
#  'BHP': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '0.34',
#          'average_price': '1766.0594',
#          'buy_price': '1734',
#          'closing_price': '1740',
#          'max_price': '1871',
#          'min_price': '1680',
#          'opening_price': '1734',
#          'sell_price': '1740',
#          'units_traded': '708297.75468545',
#          'volume_1day': '708297.75468545',
#          'volume_7day': '1456472.02053679'},
#  'BSV': {'24H_fluctate': '12900',
#          '24H_fluctate_rate': '9.13',
#          'average_price': '150979.9647',
#          'buy_price': '154000',
#          'closing_price': '154100',
#          'max_price': '163600',
#          'min_price': '138400',
#          'opening_price': '141200',
#          'sell_price': '154100',
#          'units_traded': '76990.31372257',
#          'volume_1day': '76990.31372257',
#          'volume_7day': '297027.19538424'},
#  'BTC': {'24H_fluctate': '616000',
#          '24H_fluctate_rate': '5.02',
#          'average_price': '12761552.1113',
#          'buy_price': '12876000',
#          'closing_price': '12875000',
#          'max_price': '13451000',
#          'min_price': '12110000',
#          'opening_price': '12259000',
#          'sell_price': '12885000',
#          'units_traded': '12453.8669344',
#          'volume_1day': '12453.8669344',
#          'volume_7day': '90002.84789265'},
#  'BTG': {'24H_fluctate': '1260',
#          '24H_fluctate_rate': '4.50',
#          'average_price': '29524.7609',
#          'buy_price': '29260',
#          'closing_price': '29260',
#          'max_price': '30800',
#          'min_price': '27800',
#          'opening_price': '28000',
#          'sell_price': '29270',
#          'units_traded': '22913.20460297',
#          'volume_1day': '22913.20460297',
#          'volume_7day': '240128.36575974'},
#  'BTT': {'24H_fluctate': '0.04',
#          '24H_fluctate_rate': '3.00',
#          'average_price': '1.3617',
#          'buy_price': '1.36',
#          'closing_price': '1.37',
#          'max_price': '1.53',
#          'min_price': '1.21',
#          'opening_price': '1.33',
#          'sell_price': '1.37',
#          'units_traded': '362510012.68393238',
#          'volume_1day': '362510012.68393238',
#          'volume_7day': '1521571836.38589899'},
#  'BZNT': {'24H_fluctate': '0.2',
#           '24H_fluctate_rate': '0.89',
#           'average_price': '22.753',
#           'buy_price': '22.5',
#           'closing_price': '22.6',
#           'max_price': '23.4',
#           'min_price': '22',
#           'opening_price': '22.4',
#           'sell_price': '22.8',
#           'units_traded': '4278452.93916213',
#           'volume_1day': '4278452.93916213',
#           'volume_7day': '88414336.078611064867138655'},
#  'CMT': {'24H_fluctate': '1.3',
#          '24H_fluctate_rate': '2.07',
#          'average_price': '63.784',
#          'buy_price': '63.8',
#          'closing_price': '63.9',
#          'max_price': '67.7',
#          'min_price': '60.6',
#          'opening_price': '62.6',
#          'sell_price': '63.9',
#          'units_traded': '11589542.11175267',
#          'volume_1day': '11589542.11175267',
#          'volume_7day': '321663693.622124548568758734'},
#  'CON': {'24H_fluctate': '0.3',
#          '24H_fluctate_rate': '2.17',
#          'average_price': '14.0621',
#          'buy_price': '14',
#          'closing_price': '14.1',
#          'max_price': '14.5',
#          'min_price': '13.7',
#          'opening_price': '13.8',
#          'sell_price': '14.1',
#          'units_traded': '142203116.61831457',
#          'volume_1day': '142203116.61831457',
#          'volume_7day': '1188620142.098098126919498287'},
#  'CTXC': {'24H_fluctate': '10',
#           '24H_fluctate_rate': '2.07',
#           'average_price': '498.4464',
#           'buy_price': '488',
#           'closing_price': '493',
#           'max_price': '514',
#           'min_price': '480',
#           'opening_price': '483',
#           'sell_price': '494',
#           'units_traded': '388804.93252177',
#           'volume_1day': '388804.93252177',
#           'volume_7day': '8879336.594546649042605382'},
#  'DAC': {'24H_fluctate': '-0.08',
#          '24H_fluctate_rate': '-1.40',
#          'average_price': '5.797',
#          'buy_price': '5.62',
#          'closing_price': '5.62',
#          'max_price': '6.04',
#          'min_price': '5.53',
#          'opening_price': '5.7',
#          'sell_price': '5.69',
#          'units_traded': '25689561.84780895',
#          'volume_1day': '25689561.84780895',
#          'volume_7day': '815960101.689098645147710247'},
#  'DACC': {'24H_fluctate': '0.01',
#           '24H_fluctate_rate': '6.25',
#           'average_price': '0.1647',
#           'buy_price': '0.16',
#           'closing_price': '0.17',
#           'max_price': '0.17',
#           'min_price': '0.15',
#           'opening_price': '0.16',
#           'sell_price': '0.17',
#           'units_traded': '403089352.24839411',
#           'volume_1day': '403089352.24839411',
#           'volume_7day': '2766889854.52124614'},
#  'DASH': {'24H_fluctate': '9900',
#           '24H_fluctate_rate': '6.44',
#           'average_price': '159789.6766',
#           'buy_price': '163300',
#           'closing_price': '163400',
#           'max_price': '170000',
#           'min_price': '149100',
#           'opening_price': '153500',
#           'sell_price': '163500',
#           'units_traded': '1040225.85586835',
#           'volume_1day': '1040225.85586835',
#           'volume_7day': '11266722.90049985'},
#  'ELF': {'24H_fluctate': '8',
#          '24H_fluctate_rate': '5.09',
#          'average_price': '161.4948',
#          'buy_price': '163',
#          'closing_price': '165',
#          'max_price': '170',
#          'min_price': '154',
#          'opening_price': '157',
#          'sell_price': '165',
#          'units_traded': '1089895.22880696',
#          'volume_1day': '1089895.22880696',
#          'volume_7day': '10592604.264624397487223412'},
#  'ENJ': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.65',
#          'average_price': '120.1539',
#          'buy_price': '118',
#          'closing_price': '119',
#          'max_price': '126',
#          'min_price': '115',
#          'opening_price': '121',
#          'sell_price': '119',
#          'units_traded': '15908648.60828712',
#          'volume_1day': '15908648.60828712',
#          'volume_7day': '69340593.706997812374310654'},
#  'EOS': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '0.09',
#          'average_price': '5185.1271',
#          'buy_price': '5120',
#          'closing_price': '5120',
#          'max_price': '5345',
#          'min_price': '4973',
#          'opening_price': '5115',
#          'sell_price': '5125',
#          'units_traded': '2147421.03343604',
#          'volume_1day': '2147421.03343604',
#          'volume_7day': '17628925.67139707'},
#  'ETC': {'24H_fluctate': '325',
#          '24H_fluctate_rate': '4.93',
#          'average_price': '6772.4606',
#          'buy_price': '6900',
#          'closing_price': '6905',
#          'max_price': '7105',
#          'min_price': '6430',
#          'opening_price': '6580',
#          'sell_price': '6910',
#          'units_traded': '111197.54678467',
#          'volume_1day': '111197.54678467',
#          'volume_7day': '804130.248156791870193793'},
#  'ETH': {'24H_fluctate': '7300',
#          '24H_fluctate_rate': '2.73',
#          'average_price': '275269.3698',
#          'buy_price': '273500',
#          'closing_price': '273800',
#          'max_price': '284900',
#          'min_price': '262900',
#          'opening_price': '266500',
#          'sell_price': '274000',
#          'units_traded': '112583.14087141',
#          'volume_1day': '112583.14087141',
#          'volume_7day': '610589.705887078849461332'},
#  'ETHOS': {'24H_fluctate': '3',
#            '24H_fluctate_rate': '2.00',
#            'average_price': '152.2282',
#            'buy_price': '153',
#            'closing_price': '153',
#            'max_price': '160',
#            'min_price': '144',
#            'opening_price': '150',
#            'sell_price': '154',
#            'units_traded': '2838863.67858567',
#            'volume_1day': '2838863.67858567',
#            'volume_7day': '45223318.30223607'},
#  'ETZ': {'24H_fluctate': '8',
#          '24H_fluctate_rate': '2.76',
#          'average_price': '302.9425',
#          'buy_price': '297',
#          'closing_price': '297',
#          'max_price': '318',
#          'min_price': '286',
#          'opening_price': '289',
#          'sell_price': '299',
#          'units_traded': '1213151.0949824',
#          'volume_1day': '1213151.0949824',
#          'volume_7day': '18466682.651887551552491321'},
#  'GNT': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '2.71',
#          'average_price': '76.1292',
#          'buy_price': '75.8',
#          'closing_price': '75.8',
#          'max_price': '80',
#          'min_price': '73.3',
#          'opening_price': '73.8',
#          'sell_price': '77.9',
#          'units_traded': '509642.63444313',
#          'volume_1day': '509642.63444313',
#          'volume_7day': '5937652.545275536012054078'},
#  'GTO': {'24H_fluctate': '0.4',
#          '24H_fluctate_rate': '1.46',
#          'average_price': '27.7067',
#          'buy_price': '27.6',
#          'closing_price': '27.7',
#          'max_price': '29.5',
#          'min_price': '26.3',
#          'opening_price': '27.3',
#          'sell_price': '27.7',
#          'units_traded': '2922210.57227256',
#          'volume_1day': '2922210.57227256',
#          'volume_7day': '27888346.41323324'},
#  'GXC': {'24H_fluctate': '126',
#          '24H_fluctate_rate': '6.87',
#          'average_price': '1918.9609',
#          'buy_price': '1917',
#          'closing_price': '1959',
#          'max_price': '2055',
#          'min_price': '1761',
#          'opening_price': '1833',
#          'sell_price': '1959',
#          'units_traded': '135264.15523304',
#          'volume_1day': '135264.15523304',
#          'volume_7day': '1669696.95963179'},
#  'HC': {'24H_fluctate': '120',
#         '24H_fluctate_rate': '3.04',
#         'average_price': '4183.596',
#         'buy_price': '4051',
#         'closing_price': '4059',
#         'max_price': '4500',
#         'min_price': '3835',
#         'opening_price': '3939',
#         'sell_price': '4098',
#         'units_traded': '316088.6336668',
#         'volume_1day': '316088.6336668',
#         'volume_7day': '4509909.35918372'},
#  'HDAC': {'24H_fluctate': '-0.3',
#           '24H_fluctate_rate': '-0.98',
#           'average_price': '30.5916',
#           'buy_price': '30.4',
#           'closing_price': '30.2',
#           'max_price': '32.5',
#           'min_price': '28.8',
#           'opening_price': '30.5',
#           'sell_price': '30.7',
#           'units_traded': '2876303.9598944',
#           'volume_1day': '2876303.9598944',
#           'volume_7day': '34721684.23004786'},
#  'HYC': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.10',
#          'average_price': '10.0082',
#          'buy_price': '9.91',
#          'closing_price': '9.91',
#          'max_price': '10.4',
#          'min_price': '9.73',
#          'opening_price': '9.9',
#          'sell_price': '9.92',
#          'units_traded': '61383236.20190955',
#          'volume_1day': '61383236.20190955',
#          'volume_7day': '1413869520.371760941'},
#  'ICX': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '0.58',
#          'average_price': '343.1201',
#          'buy_price': '341',
#          'closing_price': '341',
#          'max_price': '357',
#          'min_price': '332',
#          'opening_price': '339',
#          'sell_price': '346',
#          'units_traded': '372349.11308365',
#          'volume_1day': '372349.11308365',
#          'volume_7day': '3714817.41305403393693958'},
#  'INS': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '0.67',
#          'average_price': '455.4054',
#          'buy_price': '445',
#          'closing_price': '446',
#          'max_price': '488',
#          'min_price': '426',
#          'opening_price': '443',
#          'sell_price': '446',
#          'units_traded': '333362.02240741',
#          'volume_1day': '333362.02240741',
#          'volume_7day': '8542772.4102807144'},
#  'IOST': {'24H_fluctate': '0.6',
#           '24H_fluctate_rate': '5.21',
#           'average_price': '11.9695',
#           'buy_price': '11.9',
#           'closing_price': '12.1',
#           'max_price': '13',
#           'min_price': '11',
#           'opening_price': '11.5',
#           'sell_price': '12.1',
#           'units_traded': '4374745.13162112',
#           'volume_1day': '4374745.13162112',
#           'volume_7day': '39880331.797591936210584287'},
#  'ITC': {'24H_fluctate': '-5',
#          '24H_fluctate_rate': '-1.43',
#          'average_price': '355.6408',
#          'buy_price': '342',
#          'closing_price': '343',
#          'max_price': '375',
#          'min_price': '323',
#          'opening_price': '348',
#          'sell_price': '343',
#          'units_traded': '1492280.18808889',
#          'volume_1day': '1492280.18808889',
#          'volume_7day': '22389445.097999064799285311'},
#  'KNC': {'24H_fluctate': '10',
#          '24H_fluctate_rate': '4.60',
#          'average_price': '224.2995',
#          'buy_price': '223',
#          'closing_price': '227',
#          'max_price': '247',
#          'min_price': '213',
#          'opening_price': '217',
#          'sell_price': '226',
#          'units_traded': '603304.07595415',
#          'volume_1day': '603304.07595415',
#          'volume_7day': '5465619.01439698425300172'},
#  'LBA': {'24H_fluctate': '-0.8',
#          '24H_fluctate_rate': '-2.58',
#          'average_price': '31.1657',
#          'buy_price': '30.1',
#          'closing_price': '30.2',
#          'max_price': '32.3',
#          'min_price': '30.2',
#          'opening_price': '31',
#          'sell_price': '30.2',
#          'units_traded': '9095348.87089058',
#          'volume_1day': '9095348.87089058',
#          'volume_7day': '96667635.33813059765145354'},
#  'LINK': {'24H_fluctate': '-16',
#           '24H_fluctate_rate': '-0.34',
#           'average_price': '4676.2983',
#           'buy_price': '4566',
#           'closing_price': '4562',
#           'max_price': '4940',
#           'min_price': '4434',
#           'opening_price': '4578',
#           'sell_price': '4591',
#           'units_traded': '357145.71383995',
#           'volume_1day': '357145.71383995',
#           'volume_7day': '5133129.714514809153537911'},
#  'LOOM': {'24H_fluctate': '6.2',
#           '24H_fluctate_rate': '7.52',
#           'average_price': '87.244',
#           'buy_price': '88.6',
#           'closing_price': '88.6',
#           'max_price': '91.5',
#           'min_price': '81.9',
#           'opening_price': '82.4',
#           'sell_price': '90.5',
#           'units_traded': '475670.87968112',
#           'volume_1day': '475670.87968112',
#           'volume_7day': '4427647.153480573999395522'},
#  'LRC': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '73.2059',
#          'buy_price': '71.5',
#          'closing_price': '71.2',
#          'max_price': '80.8',
#          'min_price': '70.1',
#          'opening_price': '71.2',
#          'sell_price': '73.9',
#          'units_traded': '579264.17988488',
#          'volume_1day': '579264.17988488',
#          'volume_7day': '5610021.087529428809595789'},
#  'LTC': {'24H_fluctate': '1200',
#          '24H_fluctate_rate': '1.12',
#          'average_price': '108567.2166',
#          'buy_price': '107300',
#          'closing_price': '107400',
#          'max_price': '112200',
#          'min_price': '103500',
#          'opening_price': '106200',
#          'sell_price': '107400',
#          'units_traded': '21678.673598',
#          'volume_1day': '21678.673598',
#          'volume_7day': '175816.59769662'},
#  'MCO': {'24H_fluctate': '35',
#          '24H_fluctate_rate': '0.57',
#          'average_price': '6058.7761',
#          'buy_price': '6040',
#          'closing_price': '6105',
#          'max_price': '6300',
#          'min_price': '5790',
#          'opening_price': '6070',
#          'sell_price': '6120',
#          'units_traded': '44030.41554906',
#          'volume_1day': '44030.41554906',
#          'volume_7day': '256235.30326217'},
#  'MITH': {'24H_fluctate': '0.3',
#           '24H_fluctate_rate': '0.62',
#           'average_price': '47.0548',
#           'buy_price': '47.5',
#           'closing_price': '48.1',
#           'max_price': '49.4',
#           'min_price': '45.4',
#           'opening_price': '47.8',
#           'sell_price': '48.1',
#           'units_traded': '3192484.60997159',
#           'volume_1day': '3192484.60997159',
#           'volume_7day': '15599479.569708808527223843'},
#  'MIX': {'24H_fluctate': '-0.7',
#          '24H_fluctate_rate': '-1.04',
#          'average_price': '67.1719',
#          'buy_price': '66.7',
#          'closing_price': '66.6',
#          'max_price': '69.6',
#          'min_price': '64.3',
#          'opening_price': '67.3',
#          'sell_price': '67',
#          'units_traded': '2813600.91355097',
#          'volume_1day': '2813600.91355097',
#          'volume_7day': '40539489.010999805620073668'},
#  'MTL': {'24H_fluctate': '136',
#          '24H_fluctate_rate': '6.96',
#          'average_price': '2070.9794',
#          'buy_price': '2092',
#          'closing_price': '2090',
#          'max_price': '2313',
#          'min_price': '1877',
#          'opening_price': '1954',
#          'sell_price': '2108',
#          'units_traded': '138507.06332698',
#          'volume_1day': '138507.06332698',
#          'volume_7day': '638040.09100034'},
#  'NPXS': {'24H_fluctate': '0.03',
#           '24H_fluctate_rate': '4.05',
#           'average_price': '0.775',
#           'buy_price': '0.76',
#           'closing_price': '0.77',
#           'max_price': '0.82',
#           'min_price': '0.71',
#           'opening_price': '0.74',
#           'sell_price': '0.77',
#           'units_traded': '530203629.4406872',
#           'volume_1day': '530203629.4406872',
#           'volume_7day': '3212915068.192432208350640193'},
#  'OCN': {'24H_fluctate': '0.13',
#          '24H_fluctate_rate': '4.12',
#          'average_price': '3.251',
#          'buy_price': '3.22',
#          'closing_price': '3.28',
#          'max_price': '3.46',
#          'min_price': '3.09',
#          'opening_price': '3.15',
#          'sell_price': '3.29',
#          'units_traded': '13045007.88647508',
#          'volume_1day': '13045007.88647508',
#          'volume_7day': '150471486.591734292031302212'},
#  'OMG': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '0.16',
#          'average_price': '1879.1256',
#          'buy_price': '1848',
#          'closing_price': '1845',
#          'max_price': '1960',
#          'min_price': '1774',
#          'opening_price': '1842',
#          'sell_price': '1860',
#          'units_traded': '544965.69886232',
#          'volume_1day': '544965.69886232',
#          'volume_7day': '3232636.919083838164636937'},
#  'ORBS': {'24H_fluctate': '-0.09',
#           '24H_fluctate_rate': '-0.33',
#           'average_price': '29.7349',
#           'buy_price': '29.5',
#           'closing_price': '29.6',
#           'max_price': '31',
#           'min_price': '28.6',
#           'opening_price': '29.7',
#           'sell_price': '29.6',
#           'units_traded': '14329843.02417003',
#           'volume_1day': '14329843.02417003',
#           'volume_7day': '127336873.810361028319004324'},
#  'PAY': {'24H_fluctate': '13',
#          '24H_fluctate_rate': '4.94',
#          'average_price': '271.0409',
#          'buy_price': '276',
#          'closing_price': '276',
#          'max_price': '290',
#          'min_price': '255',
#          'opening_price': '263',
#          'sell_price': '277',
#          'units_traded': '215080.53693513',
#          'volume_1day': '215080.53693513',
#          'volume_7day': '3346408.22121745684417128'},
#  'PIVX': {'24H_fluctate': '219',
#           '24H_fluctate_rate': '12.31',
#           'average_price': '1975.8466',
#           'buy_price': '1931',
#           'closing_price': '1997',
#           'max_price': '2228',
#           'min_price': '1692',
#           'opening_price': '1778',
#           'sell_price': '1997',
#           'units_traded': '77830.0912423',
#           'volume_1day': '77830.0912423',
#           'volume_7day': '678025.92376624'},
#  'PLY': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.74',
#          'average_price': '13.7274',
#          'buy_price': '13.6',
#          'closing_price': '13.6',
#          'max_price': '14.4',
#          'min_price': '13.1',
#          'opening_price': '13.5',
#          'sell_price': '13.8',
#          'units_traded': '38973530.25955893',
#          'volume_1day': '38973530.25955893',
#          'volume_7day': '308892552.493790235'},
#  'POLY': {'24H_fluctate': '6.9',
#           '24H_fluctate_rate': '10.74',
#           'average_price': '75.2962',
#           'buy_price': '70.6',
#           'closing_price': '71.1',
#           'max_price': '88',
#           'min_price': '62.1',
#           'opening_price': '64.2',
#           'sell_price': '71',
#           'units_traded': '16956859.89016957',
#           'volume_1day': '16956859.89016957',
#           'volume_7day': '40392614.84739352174938958'},
#  'POWR': {'24H_fluctate': '1.1',
#           '24H_fluctate_rate': '1.11',
#           'average_price': '97.9548',
#           'buy_price': '97.4',
#           'closing_price': '99.5',
#           'max_price': '103',
#           'min_price': '92',
#           'opening_price': '98.4',
#           'sell_price': '99.5',
#           'units_traded': '901491.11027166',
#           'volume_1day': '901491.11027166',
#           'volume_7day': '7567503.35504943'},
#  'PPT': {'24H_fluctate': '26',
#          '24H_fluctate_rate': '0.76',
#          'average_price': '3438.1562',
#          'buy_price': '3418',
#          'closing_price': '3417',
#          'max_price': '3646',
#          'min_price': '3169',
#          'opening_price': '3391',
#          'sell_price': '3454',
#          'units_traded': '128559.87162431',
#          'volume_1day': '128559.87162431',
#          'volume_7day': '1894594.7212553'},
#  'PST': {'24H_fluctate': '15',
#          '24H_fluctate_rate': '11.27',
#          'average_price': '145.0753',
#          'buy_price': '147',
#          'closing_price': '148',
#          'max_price': '157',
#          'min_price': '126',
#          'opening_price': '133',
#          'sell_price': '148',
#          'units_traded': '5158551.49142081',
#          'volume_1day': '5158551.49142081',
#          'volume_7day': '21393943.696764452474168705'},
#  'QTUM': {'24H_fluctate': '166',
#           '24H_fluctate_rate': '4.40',
#           'average_price': '3929.9641',
#           'buy_price': '3932',
#           'closing_price': '3932',
#           'max_price': '4152',
#           'min_price': '3691',
#           'opening_price': '3766',
#           'sell_price': '3946',
#           'units_traded': '456648.08630091',
#           'volume_1day': '456648.08630091',
#           'volume_7day': '3662592.16320776'},
#  'RDN': {'24H_fluctate': '69',
#          '24H_fluctate_rate': '7.36',
#          'average_price': '993.9623',
#          'buy_price': '995',
#          'closing_price': '1006',
#          'max_price': '1116',
#          'min_price': '861',
#          'opening_price': '937',
#          'sell_price': '1004',
#          'units_traded': '353299.84651671',
#          'volume_1day': '353299.84651671',
#          'volume_7day': '1985078.380822857785250504'},
#  'REP': {'24H_fluctate': '1380',
#          '24H_fluctate_rate': '7.58',
#          'average_price': '20601.2966',
#          'buy_price': '19570',
#          'closing_price': '19570',
#          'max_price': '24700',
#          'min_price': '18030',
#          'opening_price': '18190',
#          'sell_price': '19580',
#          'units_traded': '61134.53745455',
#          'volume_1day': '61134.53745455',
#          'volume_7day': '186632.862267004532677142'},
#  'RNT': {'24H_fluctate': '-0.8',
#          '24H_fluctate_rate': '-1.86',
#          'average_price': '41.7773',
#          'buy_price': '41.8',
#          'closing_price': '42.1',
#          'max_price': '43.9',
#          'min_price': '40.5',
#          'opening_price': '42.9',
#          'sell_price': '42.1',
#          'units_traded': '2177818.41083142',
#          'volume_1day': '2177818.41083142',
#          'volume_7day': '29868823.313498959215133828'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.0447',
#          'buy_price': '0.04',
#          'closing_price': '0.05',
#          'max_price': '0.05',
#          'min_price': '0.04',
#          'opening_price': '0.05',
#          'sell_price': '0.05',
#          'units_traded': '1192858968.64948',
#          'volume_1day': '1192858968.64948',
#          'volume_7day': '19388130956.612640000000000003'},
#  'SALT': {'24H_fluctate': '2',
#           '24H_fluctate_rate': '0.95',
#           'average_price': '212.1785',
#           'buy_price': '205',
#           'closing_price': '211',
#           'max_price': '228',
#           'min_price': '203',
#           'opening_price': '209',
#           'sell_price': '211',
#           'units_traded': '418781.28054619',
#           'volume_1day': '418781.28054619',
#           'volume_7day': '2723803.57035264'},
#  'SNT': {'24H_fluctate': '0.9',
#          '24H_fluctate_rate': '3.75',
#          'average_price': '24.7877',
#          'buy_price': '24.9',
#          'closing_price': '24.9',
#          'max_price': '26.1',
#          'min_price': '23.7',
#          'opening_price': '24',
#          'sell_price': '25.1',
#          'units_traded': '4846972.1610606',
#          'volume_1day': '4846972.1610606',
#          'volume_7day': '52986411.83796821656894206'},
#  'STEEM': {'24H_fluctate': '3',
#            '24H_fluctate_rate': '0.77',
#            'average_price': '396.2231',
#            'buy_price': '388',
#            'closing_price': '392',
#            'max_price': '412',
#            'min_price': '375',
#            'opening_price': '389',
#            'sell_price': '392',
#            'units_traded': '605165.6744111',
#            'volume_1day': '605165.6744111',
#            'volume_7day': '12069056.74096723'},
#  'STRAT': {'24H_fluctate': '104',
#            '24H_fluctate_rate': '7.55',
#            'average_price': '1481.6235',
#            'buy_price': '1472',
#            'closing_price': '1481',
#            'max_price': '1600',
#            'min_price': '1351',
#            'opening_price': '1377',
#            'sell_price': '1483',
#            'units_traded': '256001.1349581',
#            'volume_1day': '256001.1349581',
#            'volume_7day': '1708174.34160385'},
#  'THETA': {'24H_fluctate': '3',
#            '24H_fluctate_rate': '2.67',
#            'average_price': '114.7019',
#            'buy_price': '113',
#            'closing_price': '115',
#            'max_price': '122',
#            'min_price': '110',
#            'opening_price': '112',
#            'sell_price': '115',
#            'units_traded': '714819.27476316',
#            'volume_1day': '714819.27476316',
#            'volume_7day': '6043668.710096666985828777'},
#  'TMTG': {'24H_fluctate': '0.04',
#           '24H_fluctate_rate': '1.86',
#           'average_price': '2.1827',
#           'buy_price': '2.16',
#           'closing_price': '2.19',
#           'max_price': '2.27',
#           'min_price': '2.07',
#           'opening_price': '2.15',
#           'sell_price': '2.19',
#           'units_traded': '48143681.73084638',
#           'volume_1day': '48143681.73084638',
#           'volume_7day': '283304937.835342867958841878'},
#  'TRUE': {'24H_fluctate': '15',
#           '24H_fluctate_rate': '2.85',
#           'average_price': '553.5091',
#           'buy_price': '539',
#           'closing_price': '540',
#           'max_price': '598',
#           'min_price': '515',
#           'opening_price': '525',
#           'sell_price': '540',
#           'units_traded': '573458.36841174',
#           'volume_1day': '573458.36841174',
#           'volume_7day': '4526428.474098785681782811'},
#  'TRX': {'24H_fluctate': '-0.4',
#          '24H_fluctate_rate': '-1.36',
#          'average_price': '29.3717',
#          'buy_price': '28.7',
#          'closing_price': '28.8',
#          'max_price': '30.3',
#          'min_price': '28.4',
#          'opening_price': '29.2',
#          'sell_price': '28.8',
#          'units_traded': '72224395.8183904',
#          'volume_1day': '72224395.8183904',
#          'volume_7day': '571726052.32302103'},
#  'VALOR': {'24H_fluctate': '117',
#            '24H_fluctate_rate': '4.78',
#            'average_price': '2558.098',
#            'buy_price': '2520',
#            'closing_price': '2562',
#            'max_price': '2696',
#            'min_price': '2403',
#            'opening_price': '2445',
#            'sell_price': '2536',
#            'units_traded': '104380.62444095',
#            'volume_1day': '104380.62444095',
#            'volume_7day': '1144979.578867059660038435'},
#  'VET': {'24H_fluctate': '0.3',
#          '24H_fluctate_rate': '4.14',
#          'average_price': '7.4273',
#          'buy_price': '7.51',
#          'closing_price': '7.53',
#          'max_price': '7.78',
#          'min_price': '7.19',
#          'opening_price': '7.23',
#          'sell_price': '7.6',
#          'units_traded': '14275922.83097113',
#          'volume_1day': '14275922.83097113',
#          'volume_7day': '138100467.508215197939690796'},
#  'WAVES': {'24H_fluctate': '492',
#            '24H_fluctate_rate': '23.00',
#            'average_price': '2735.6041',
#            'buy_price': '2630',
#            'closing_price': '2631',
#            'max_price': '3250',
#            'min_price': '2075',
#            'opening_price': '2139',
#            'sell_price': '2673',
#            'units_traded': '810157.09894027',
#            'volume_1day': '810157.09894027',
#            'volume_7day': '1407174.05416476'},
#  'WAX': {'24H_fluctate': '3.2',
#          '24H_fluctate_rate': '5.07',
#          'average_price': '64.3618',
#          'buy_price': '65.6',
#          'closing_price': '66.2',
#          'max_price': '70',
#          'min_price': '61.9',
#          'opening_price': '63',
#          'sell_price': '66.2',
#          'units_traded': '1870865.10659123',
#          'volume_1day': '1870865.10659123',
#          'volume_7day': '17542664.34149504'},
#  'WET': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-0.66',
#          'average_price': '15.27',
#          'buy_price': '15',
#          'closing_price': '15',
#          'max_price': '15.8',
#          'min_price': '14.8',
#          'opening_price': '15.1',
#          'sell_price': '15.1',
#          'units_traded': '11671328.04244334',
#          'volume_1day': '11671328.04244334',
#          'volume_7day': '132503912.331412025431120464'},
#  'WTC': {'24H_fluctate': '100',
#          '24H_fluctate_rate': '3.89',
#          'average_price': '2754.2821',
#          'buy_price': '2617',
#          'closing_price': '2669',
#          'max_price': '3105',
#          'min_price': '2548',
#          'opening_price': '2569',
#          'sell_price': '2663',
#          'units_traded': '230856.15851654',
#          'volume_1day': '230856.15851654',
#          'volume_7day': '5304718.173220448284851752'},
#  'XEM': {'24H_fluctate': '3.1',
#          '24H_fluctate_rate': '3.16',
#          'average_price': '98.5543',
#          'buy_price': '98.4',
#          'closing_price': '101',
#          'max_price': '104',
#          'min_price': '92.7',
#          'opening_price': '97.9',
#          'sell_price': '101',
#          'units_traded': '1093509.99266868',
#          'volume_1day': '1093509.99266868',
#          'volume_7day': '12199783.33032243'},
#  'XLM': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.89',
#          'average_price': '112.3355',
#          'buy_price': '112',
#          'closing_price': '113',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '112',
#          'sell_price': '114',
#          'units_traded': '2688510.79163372',
#          'volume_1day': '2688510.79163372',
#          'volume_7day': '23204333.76321197'},
#  'XMR': {'24H_fluctate': '3300',
#          '24H_fluctate_rate': '3.36',
#          'average_price': '97133.7019',
#          'buy_price': '100700',
#          'closing_price': '101300',
#          'max_price': '107700',
#          'min_price': '90300',
#          'opening_price': '98000',
#          'sell_price': '101500',
#          'units_traded': '3932542.84322706',
#          'volume_1day': '3932542.84322706',
#          'volume_7day': '17506172.048910047431'},
#  'XRP': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '378.9933',
#          'buy_price': '375',
#          'closing_price': '376',
#          'max_price': '391',
#          'min_price': '369',
#          'opening_price': '376',
#          'sell_price': '376',
#          'units_traded': '85581554.75985859',
#          'volume_1day': '85581554.75985859',
#          'volume_7day': '649110466.19331539'},
#  'XVG': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.67',
#          'average_price': '14.7085',
#          'buy_price': '14.7',
#          'closing_price': '15',
#          'max_price': '15.7',
#          'min_price': '13.9',
#          'opening_price': '14.9',
#          'sell_price': '15',
#          'units_traded': '1718658.81202629',
#          'volume_1day': '1718658.81202629',
#          'volume_7day': '21725142.38678206'},
#  'ZEC': {'24H_fluctate': '3100',
#          '24H_fluctate_rate': '3.00',
#          'average_price': '105143.5137',
#          'buy_price': '106000',
#          'closing_price': '106400',
#          'max_price': '113300',
#          'min_price': '96200',
#          'opening_price': '103300',
#          'sell_price': '106400',
#          'units_traded': '2095.82464529',
#          'volume_1day': '2095.82464529',
#          'volume_7day': '15711.75840851'},
#  'ZIL': {'24H_fluctate': '0.8',
#          '24H_fluctate_rate': '4.90',
#          'average_price': '16.9669',
#          'buy_price': '17',
#          'closing_price': '17.1',
#          'max_price': '17.5',
#          'min_price': '16.3',
#          'opening_price': '16.3',
#          'sell_price': '17.1',
#          'units_traded': '7230290.99435369',
#          'volume_1day': '7230290.99435369',
#          'volume_7day': '61776527.250081790174'},
#  'ZRX': {'24H_fluctate': '42',
#          '24H_fluctate_rate': '16.09',
#          'average_price': '304.1947',
#          'buy_price': '303',
#          'closing_price': '303',
#          'max_price': '328',
#          'min_price': '256',
#          'opening_price': '261',
#          'sell_price': '305',
#          'units_traded': '1591059.56589439',
#          'volume_1day': '1591059.56589439',
#          'volume_7day': '4534754.471622466409196126'},
#  'date': '1563251844467'}

# %%
for key in data.keys():
    if key == 'date':
        continue
    change = float(data[key]['max_price']) - float(data[key]['min_price'])
    result = change + float(data[key]['opening_price'])
    
    if result > float(data[key]['max_price']):
        print('상승장')
    else:
        print('하락장')
# Out:
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 하락장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 하락장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장

# %%
# 선생님 코드

for coin, coin_data in data.items():
#   if type(coin_data) != type(dict()):
#       continue
    if type(coin_data) == type(dict()):
        if float(coin_data['opening_price']) - float(coin_data['min_price']) > 0:
            print('상승장')
        else:
            print('하락장')
# Out:
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 하락장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 하락장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장

# %% [markdown]
# # 평균점수
# > 다음 딕셔너리에서 평균 점수를 출력하라

# %%
student = {'python':80, 'algorithm':78, 'django':95, 'flask':80}

# %%
result = 0
for value in student.values():
    result += value
print(f'평균 점수는 {result / len(student)}입니다.')
# Out:
# 평균 점수는 83.25입니다.

# %%
# 선생님 코드★
count = 0
total_score = 0
for key in student:
    total_score += student[key]
    count += 1
print(total_score/count)
# Out:
# 83.25

# %%
# 선생님 코드 
sum(student.values()) / len(student)
# Out:
# 83.25

# %%
list(student.values())
# Out:
# [80, 78, 95, 80]

# %% [markdown]
# # 혈액형
# > 학생들의 혈액형(A,B,O,AB)에 대한 데이터가 리스트에 들어있다. 각 혈액형이 몇명인지 딕셔너리를 만들어 출력하라

# %%
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']

# %%
# 1. 기본이 되는 코드

A = 0
B = 0
AB = 0
O = 0

for blood_type in blood:
    if blood_type == 'A':
        A += 1
    elif blood_type == 'B':
        B += 1
    elif blood_type == 'AB':
        AB += 1
    else:
        O += 1
print({'A': A, 'B': B, 'AB': AB, 'O':O})
# Out:
# {'A': 5, 'B': 2, 'AB': 3, 'O': 4}

# %%
# 2. 여기에서 머리를 써서 만들자
blood_dict = {}

# (반복) 하나씩 꺼내서 확인한다.
for blood_type in blood:
    # 지금 나온적이 없으면, 키와 value 1로 만든다. 
    if blood_type not in blood_dict.keys():
        blood_dict[blood_type] = 1
    else:
        blood_dict[blood_type] += 1
print(blood_dict)
# Out:
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}

# %%
{blood_type: blood.count(blood_type) for blood_type in set(blood)}
# Out:
# {'B': 2, 'A': 5, 'O': 4, 'AB': 3}

# %% [markdown]
# # UBD
# > movies는 영화제목이 key로 누적관객수가 value인 딕셔너리이다.
# >
# > 자전차왕 엄복동의 누적관객수는 172212명이고 172212명을 1UBD라고 할때 80UBD를 넘지 못하는 영화를 출력하라.

# %%
movies = {
    "7번방의선물":12811206,
    "괴물":13019740,
    "국제시장":14257115,
    "극한직업":16261018,
    "도둑들":12983330,
    "명량":17613682,
    "베테랑":13414009,
    "신과함께-죄와벌":14410754,
    "아바타":13624328,
    "어벤져스:엔드게임":13901423,
}

# %%
for key, value in movies.items():
    if value <= 80 * 172212:
        print(key)
# Out:
# 7번방의선물
# 괴물
# 도둑들
# 베테랑
# 아바타
